# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_csv('data.csv')

# %%
newData = data.loc[data['case_status'].astype(str).str.lower() == "certified"]

# %% [markdown]
# #####  Assuming a employee works for 40 hours per week and each month has 4 weeks. So to convert hourly salary to yearly, I multiple hourly salary * 4 * 40 * 12.
# ##### Current approach for Nan in wage_unit, if wage_offer is less than 100, I am assuming, it will be an hourly salary. So assigning and the wages to show yearly salary

# %%
for idi, row in newData.iterrows():
    if str(row['wage_unit']).lower() == 'hour':
        newData.loc[idi, 'wage_offer'] = newData.loc[idi, 'wage_offer'] * 40 * 4 * 12
        newData.loc[idi, 'wage_unit'] = 'Year'
        
    elif not pd.notnull(row['wage_unit']):
        if newData.loc[idi, 'wage_offer'] < 100:
            newData.loc[idi, 'wage_offer'] = newData.loc[idi, 'wage_offer'] * 40 * 4 * 12
            newData.loc[idi, 'wage_unit'] = 'Year'
        else:
            newData.loc[idi, 'wage_unit'] = 'Year'
# Out:
# /home/rohit/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# ##### Since all the wages are in yearly form, I drop 'wage_unit' column

# %%
newData = newData.drop('wage_unit', axis = 1)

# %% [markdown]
# ##### We don't need 'job_foreign_lang_req', 'case_number', 'case_received_date', 'decision_date', 'employer_yr_established'

# %%
newData = newData.drop(['job_foreign_lang_req', 'case_number', 'case_received_date', 'decision_date', 'employer_yr_established'], axis = 1)

# %%
def num_missing(x):
  return sum(x.isnull())

# %%
print newData.apply(num_missing, axis=0)
# Out:
# case_status                      0
# employer_name                    0
# employer_num_employees           0
# job_education                    0
# job_experience_num_months    16933
# job_state                        0
# job_level                     2653
# employee_citizenship             0
# wage_offer                       0
# dtype: int64

# %% [markdown]
# ##### NAN in 'job_experience_num_months'. I am grouping the 'job_level' values and for each 'job_level' value, I am taking the average of present 'job_experience_num_months' and I am assigning it to the NAN values of 'job_experience_num_months' for that 'job_level'.
# ##### Because of the above assumption, I am deleting the rows where 'job_level' are NAN, in most of the cases, 'job_experience_num_months' and 'job_level' are NAN.

# %%
newData = newData.loc[newData['job_level'].astype(str).str.lower() != 'nan']

# %%
print newData.apply(num_missing, axis=0)
# Out:
# case_status                      0
# employer_name                    0
# employer_num_employees           0
# job_education                    0
# job_experience_num_months    15430
# job_state                        0
# job_level                        0
# employee_citizenship             0
# wage_offer                       0
# dtype: int64

# %%
def fill_job_months(df):
    filter_df1 = df.loc[df['job_experience_num_months'].astype(str).str.lower() != 'nan']
    group_job_level_df = filter_df1.groupby('job_level')['job_experience_num_months'].mean()
    for i, row in df.iterrows():
        if str(row['job_experience_num_months']).lower() == 'nan':
            if str(row['job_level']).lower() != 'nan':
                df.loc[i, 'job_experience_num_months'] = group_job_level_df[row['job_level']]
    return df

# %%
newData = fill_job_months(newData)

# %% [markdown]
# ##### We don't need 'case_status' because all of them are 'Certified'

# %%
newData = newData.drop('case_status', axis = 1)

# %%
print newData.apply(num_missing, axis=0)
# Out:
# employer_name                0
# employer_num_employees       0
# job_education                0
# job_experience_num_months    0
# job_state                    0
# job_level                    0
# employee_citizenship         0
# wage_offer                   0
# dtype: int64

# %% [markdown]
# ##### Now I have zero NAN values in every column. Now important features can be extracted and model can be trained.

# %% [markdown]
# ##### Initially I am performing one hot enconding on categorical features

# %%
def change_categorical(data, cat):
    le = preprocessing.LabelEncoder()
    le.fit(data.values[:, cat])
    return le.transform(data.values[:, cat])

# %%
categories = [0, 2, 4, 6]
name = {0: 'employer_name', 2: 'job_education', 4: 'job_state', 6: 'employee_citizenship'}
for cat in categories:
    newData[name[cat]] = change_categorical(newData, cat)

# %%
newData
# Out:
#        employer_name  employer_num_employees  job_education  \
# 0               1483                   149.0              1
# 2              10843                  5600.0              2
# 3              10843                  5600.0              2
# 4              10843                  5600.0              2
# 5              10843                  5600.0              2
# 9               2248                    48.0              4
# 14              6903                     8.0              5
# 24              6335                    90.0              1
# 28              3552                    40.0              5
# 35               526                 33010.0              1
# 37               704                 17787.0              1
# 43              9149                     5.0              5
# 53              1703                    47.0              1
# 86              3478                  4500.0              4
# 125             8335                     5.0              5
# 157             7841                   126.0              5
# 169               96                    72.0              4
# 195             9179                  4816.0              1
# 205              514                 90000.0              4
# 207             7649                    60.0              1
# 311             4794                 91000.0              1
# 469              882                256420.0              1
# 566             5704                    50.0              5
# 570             3846                    21.0              6
# 575            10374                   107.0              4
# 624             7584                    89.0              5
# 625             5231                 20000.0              1
# 628              882                266590.0              1
# 630              227                    80.0              4
# 632              652                  1000.0              1
# ...              ...                     ...            ...
# 60184           2555                   580.0              4
# 60186           4116                 12443.0              1
# 60188           1565                    49.0              4
# 60190           8063                    12.0              5
# 60191            935                    10.0              5
# 60192             69                   883.0              4
# 60193           4774                   149.0              4
# 60194             69                   883.0              4
# 60195             69                   883.0              4
# 60197             69                   883.0              4
# 60198             69                   883.0              4
# 60200             69                   883.0              4
# 60201             69                   883.0              4
# 60202           4498                   750.0              5
# 60203           4498                   750.0              5
# 60204           4498                   750.0              5
# 60205           2973                  5200.0              5
# 60206           2973                  5200.0              5
# 60207           2107                    45.0              4
# 60208           2149                 35000.0              1
# 60209           2973                  5200.0              5
# 60210           1908                   170.0              4
# 60211           8559                 10389.0              1
# 60212             69                   883.0              4
# 60213             69                   883.0              4
# 60215           8495                    14.0              4
# 60217            773                   160.0              4
# 60222           1528                    50.0              1
# 60467           3474                  7185.0              1
# 61612           5205                   200.0              4
#
#        job_experience_num_months  job_state  job_level  employee_citizenship  \
# 0                      19.822651          4        1.0                   119
# 2                      17.342026         52        2.0                    65
# 3                      84.000000         52        3.0                    29
# 4                      19.822651         52        1.0                     5
# 5                      17.342026         52        2.0                    29
# 9                      24.000000         15        2.0                   157
# 14                     12.000000         34        2.0                   155
# 24                     60.000000         34        2.0                   114
# 28                     36.000000         34        3.0                    29
# 35                     60.000000          2        3.0                    65
# 37                     60.000000          4        3.0                    65
# 43                     24.000000         34        2.0                    91
# 53                     50.037658         34        4.0                    96
# 86                     12.000000         43        3.0                    65
# 125                    50.037658         32        4.0                    71
# 157                    72.000000         54        2.0                    96
# 169                    36.000000         47        4.0                    65
# 195                    19.822651         47        1.0                    96
# 205                    17.342026         47        2.0                   111
# 207                    60.000000         47        4.0                    65
# 311                    24.000000          4        2.0                    65
# 469                    17.342026         24        2.0                    29
# 566                    24.000000         34        1.0                   161
# 570                    17.342026          4        2.0                    61
# 575                    12.000000         22        2.0                    65
# 624                     6.000000         34        3.0                    96
# 625                    19.822651         40        1.0                    65
# 628                    19.822651         52        1.0                    65
# 630                    17.342026         15        2.0                    65
# 632                    24.000000         41        1.0                   131
# ...                          ...        ...        ...                   ...
# 60184                   6.000000         24        2.0                    65
# 60186                  19.822651          4        1.0                     7
# 60188                  12.000000         51        3.0                   101
# 60190                  24.000000         34        3.0                    37
# 60191                  24.000000         47        3.0                   145
# 60192                  50.037658         15        4.0                    65
# 60193                  12.000000         47        2.0                    65
# 60194                  50.037658         15        4.0                    65
# 60195                  50.037658         15        4.0                    65
# 60197                  50.037658         15        4.0                    65
# 60198                  17.342026         15        2.0                    65
# 60200                  25.653858         15        3.0                    65
# 60201                  50.037658         15        4.0                    31
# 60202                  19.822651         44        1.0                   131
# 60203                  19.822651         44        1.0                   131
# 60204                  19.822651         44        1.0                   131
# 60205                  19.822651         35        1.0                    31
# 60206                  19.822651         35        1.0                    31
# 60207                  17.342026         15        2.0                    65
# 60208                  60.000000         47        4.0                    65
# 60209                  19.822651         35        1.0                    31
# 60210                  12.000000         11        4.0                    65
# 60211                  60.000000          4        4.0                    65
# 60212                  50.037658         15        4.0                    29
# 60213                  50.037658         15        4.0                   159
# 60215                  12.000000          4        2.0                   114
# 60217                  17.342026          4        2.0                    65
# 60222                  60.000000         47        4.0                    22
# 60467                  24.000000          4        1.0                   139
# 61612                  25.653858          4        3.0                    65
#
#        wage_offer
# 0         30285.0
# 2        125000.0
# 3        105300.0
# 4        114285.0
# 5         88400.0
# 9         60258.0
# 14        48076.8
# 24        93700.0
# 28        81000.0
# 35        87500.0
# 37       105400.0
# 43        41011.2
# 53        80787.0
# 86        86000.0
# 125       28800.0
# 157       88816.0
# 169      135000.0
# 195       45000.0
# 205       68000.0
# 207       88005.0
# 311       69160.0
# 469       73730.0
# 566       44512.0
# 570       77025.0
# 575       91874.0
# 624       27398.4
# 625       48000.0
# 628       76020.0
# 630       58000.0
# 632       96325.0
# ...           ...
# 60184     80200.0
# 60186     88254.0
# 60188    107702.0
# 60190     45500.0
# 60191     42411.0
# 60192    135000.0
# 60193     72300.0
# 60194    140000.0
# 60195    137500.0
# 60197    136573.0
# 60198    123552.0
# 60200    140000.0
# 60201    155000.0
# 60202     14784.0
# 60203     14784.0
# 60204     14784.0
# 60205     15532.8
# 60206     15532.8
# 60207     79289.6
# 60208     76378.0
# 60209     15532.8
# 60210    136200.0
# 60211    141794.0
# 60212    155000.0
# 60213    140566.0
# 60215     79040.0
# 60217     84448.0
# 60222    114504.0
# 60467    112000.0
# 61612     97286.4
#
# [35277 rows x 8 columns]

# %%
feature_matrix_df = newData.iloc[:, :-1]
labels_df = newData.iloc[:, -1]
feature_matrix = feature_matrix_df.values
labels = labels_df.values

train_data, test_data, train_labels, test_labels = train_test_split(feature_matrix, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ##### Linear Regression

# %%
reg = LinearRegression().fit(train_data, train_labels)

# %%
pred = reg.predict(test_data)

# %%
mean_absolute_error(test_labels, pred)
# Out:
# 36842.990892288515

# %% [markdown]
# ##### Decision Tree Regressor

# %%
tree_regressor = DecisionTreeRegressor(random_state = 0).fit(train_data, train_labels)
pred1 = tree_regressor.predict(test_data)

# %%
mean_absolute_error(test_labels, pred1)
# Out:
# 30371.633567632824

# %% [markdown]
# ##### Random Forest Regressor

# %%
forest_regressor = RandomForestRegressor(n_estimators = 300, random_state = 0)
forest_regressor.fit(train_data, train_labels)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
pred2 = forest_regressor.predict(test_data)

# %%
mean_absolute_error(test_labels, pred2)
# Out:
# 26649.617464589526
